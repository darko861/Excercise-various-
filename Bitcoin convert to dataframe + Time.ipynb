# %%
import cryptocompare
import datetime
import pandas as pd

# %%
test = cryptocompare.get_historical_price_hour('BTC', 'EUR', limit=24)
test
# Out:
# [{'time': 1588593600,
#   'close': 7996.01,
#   'high': 8024.45,
#   'low': 7939.89,
#   'open': 7964.18,
#   'volumefrom': 942.21,
#   'volumeto': 7529375.74},
#  {'time': 1588597200,
#   'close': 8104.62,
#   'high': 8112.73,
#   'low': 7996.01,
#   'open': 7996.01,
#   'volumefrom': 1249.32,
#   'volumeto': 10059121.08},
#  {'time': 1588600800,
#   'close': 8070.59,
#   'high': 8123.68,
#   'low': 8068.61,
#   'open': 8104.62,
#   'volumefrom': 1042.06,
#   'volumeto': 8437386.44},
#  {'time': 1588604400,
#   'close': 8130.19,
#   'high': 8130.19,
#   'low': 8068.67,
#   'open': 8070.59,
#   'volumefrom': 615.61,
#   'volumeto': 4986925.15},
#  {'time': 1588608000,
#   'close': 8123.28,
#   'high': 8169.08,
#   'low': 8095.56,
#   'open': 8130.19,
#   'volumefrom': 867.62,
#   'volumeto': 7056667.27},
#  {'time': 1588611600,
#   'close': 8093.27,
#   'high': 8138.02,
#   'low': 8051.91,
#   'open': 8123.28,
#   'volumefrom': 776.25,
#   'volumeto': 6273649.47},
# ...

# %%
test1 = pd.DataFrame(test)
test1
# Out:
#           time    close     high      low     open  volumefrom     volumeto
# 0   1588593600  7996.01  8024.45  7939.89  7964.18      942.21   7529375.74
# 1   1588597200  8104.62  8112.73  7996.01  7996.01     1249.32  10059121.08
# 2   1588600800  8070.59  8123.68  8068.61  8104.62     1042.06   8437386.44
# 3   1588604400  8130.19  8130.19  8068.67  8070.59      615.61   4986925.15
# 4   1588608000  8123.28  8169.08  8095.56  8130.19      867.62   7056667.27
# 5   1588611600  8093.27  8138.02  8051.91  8123.28      776.25   6273649.47
# 6   1588615200  8135.67  8150.39  8091.36  8093.27      462.42   3756162.18
# 7   1588618800  8122.24  8157.09  8104.86  8135.67      680.32   5533768.55
# 8   1588622400  8196.38  8202.24  8119.77  8122.24      817.11   6675953.78
# 9   1588626000  8214.17  8217.23  8164.74  8196.38      397.41   3255599.22
# 10  1588629600  8149.71  8225.95  8137.66  8214.17      730.58   5971979.64
# ...

# %%
test1["time"] = pd.to_datetime(test1["time"], unit = "s")

# %%
test1
# Out:
#                   time    close     high      low     open  volumefrom  \
# 0  2020-05-04 12:00:00  7996.01  8024.45  7939.89  7964.18      942.21
# 1  2020-05-04 13:00:00  8104.62  8112.73  7996.01  7996.01     1249.32
# 2  2020-05-04 14:00:00  8070.59  8123.68  8068.61  8104.62     1042.06
# 3  2020-05-04 15:00:00  8130.19  8130.19  8068.67  8070.59      615.61
# 4  2020-05-04 16:00:00  8123.28  8169.08  8095.56  8130.19      867.62
# 5  2020-05-04 17:00:00  8093.27  8138.02  8051.91  8123.28      776.25
# 6  2020-05-04 18:00:00  8135.67  8150.39  8091.36  8093.27      462.42
# 7  2020-05-04 19:00:00  8122.24  8157.09  8104.86  8135.67      680.32
# 8  2020-05-04 20:00:00  8196.38  8202.24  8119.77  8122.24      817.11
# 9  2020-05-04 21:00:00  8214.17  8217.23  8164.74  8196.38      397.41
# 10 2020-05-04 22:00:00  8149.71  8225.95  8137.66  8214.17      730.58
# 11 2020-05-04 23:00:00  8155.18  8179.84  8111.70  8149.71      580.09
# ...
